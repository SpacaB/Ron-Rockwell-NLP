# %% [markdown]
# Before we do anything, we'll import some libraries that we'll need for the exercise.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk import FreqDist
from __future__ import division

# %% [markdown]
# I originally wrote my short story in Microsoft Word. To convert it to a text file, I just copied & pasted the story from Word into a .txt in Notepad++. Now we have an easy-to-work-with format: the entirety of Ron Rockwell in just a text file. Let's open it with Python.

# %%
storytext = open("ronrockwell.txt").read()

# %% [markdown]
# Next, we'll write a function that further preprocesses the text. The output is an object that consists of all the words found in Ron Rockwell as word "tokens".

# %%
def preprocess(sentence):
	sentence = sentence.lower()
	tokenizer = RegexpTokenizer(r'\w+')
	tokens = tokenizer.tokenize(sentence)
	return " ".join(tokens)

preprocessedStory = preprocess(storytext)

tokens = nltk.word_tokenize(preprocessedStory)
print tokens
# Out:
# ['\xef', 'that', 's', 'it', 'for', 'today', 'remember', 'homework', 'is', 'due', 'next', 'class', 'and', 'don', 't', 'forget', 'we', 'have', 'a', 'test', 'on', 'friday', 'on', 'everything', 'we', 've', 'learned', 'through', 'the', 'chain', 'rule', 'i', 'll', 'be', 'in', 'my', 'office', 'on', 'wednesday', 'from', 'twelve', 'to', 'two', 'and', 'thursday', 'from', 'three', 'to', 'four', 'college', 'calculus', 'is', 'boring', 'it', 's', 'boring', 'for', 'the', 'students', 'they', 'have', 'to', 'do', 'homework', 'and', 'study', 'for', 'tests', 'even', 'though', 'many', 'of', 'them', 'are', 'only', 'in', 'the', 'class', 'to', 'fulfill', 'a', 'degree', 'requirement', 'it', 's', 'boring', 'for', 'the', 'professor', 'he', 'has', 'to', 'come', 'to', 'class', 'and', 'stand', 'in', 'front', 'of', '45', 'students', 'many', 'of', 'whom', 'are', 'surfing', 'the', 'web', 'or', 'simply', 'copying', 'down', 'notes', 'like', 'a', 'robot', 'few', 'people', 'can', 'find', 'something', 'exciting', 'about', 'a', 'college', 'calculus', 'course', 'in', 'this', 'sense', 'ron', 'rockwell', 'is', 'the', 'perfect', 'college', 'calculus', 'professor', 'his', 'life', 'like', 'college', 'calculus', 'has', 'been', 'boring', 'his', 'weeks', 'consist', 'of', 'teaching', 'three', 'college', 'calculus', 'courses', 'a', 'differential', 'equations', 'course', 'and', 'doing', 'research', 'in', 'mathematics', 'things', 'are', 'almost', 'too', 'steady', 'for', 'ron', 'rarely', 'does', 'he', 'get', 'excited', 'because', 'there', 'are', 'so', 'few', 'things', 'for', 'ron', 'to', 'get', 'excited', 'about', 'ron', 'tried', 'to', 'do', 'a', 'career', 'and', 'live', 'a', 'comfortable', 'normal', 'life', 'like', 'he', 's', 'always', 'been', 'able', 'to', 'ron', 'succeeded', 'and', 'accomplished', 'those', 'goals', 'he', 'earned', 'a', 'degree', 'in', 'mathematics', 'from', 'brigham', 'young', 'university', 'and', 'though', 'he', 'wasn', 't', 'exactly', 'into', 'the', 'mormon', 'scene', 'he', 'took', 'comfort', 'in', 'the', 'structure', 'and', 'peacefulness', 'of', 'the', 'culture', 'ron', 'has', 'been', 'described', 'by', 'his', 'colleagues', 'as', 'quite', 'passive', 'and', 'risk', 'averse', 'with', 'a', 'touch', 'of', 'arrogance', 'ron', 'went', 'on', 'to', 'work', 'in', 'insurance', 'and', 'set', 'a', 'goal', 'to', 'pass', 'the', 'exams', 'required', 'in', 'order', 'to', 'get', 'certified', 'as', 'an', 'enrolled', 'actuary', 'this', 'was', 'no', 'problem', 'for', 'ron', 'and', 'by', 'age', '30', 'he', 'was', 'earning', '85', '000', 'per', 'year', 'he', 'could', 'have', 'negotiated', 'a', 'raise', 'but', 'to', 'ron', 'it', 'wasn', 't', 'worth', 'trouble', 'by', 'age', '40', 'he', 'was', 'earning', '90', '000', 'per', 'year', 'on', 'his', 'fiftieth', 'birthday', 'ron', 'quit', 'his', 'job', 'to', 'pursue', 'a', 'career', 'as', 'a', 'math', 'professor', 'ron', 'got', 'fed', 'up', 'with', 'crunching', 'numbers', 'for', 'people', 'who', 'sell', 'insurance', 'actually', 'ron', 'was', 'getting', 'fed', 'up', 'with', 'a', 'lot', 'of', 'things', 'his', 'failed', 'marriages', 'his', 'neighbors', 'and', 'the', 'general', 'monotony', 'of', 'daily', 'life', 'in', 'second', 'rate', 'new', 'jersey', 'suburbs', 'ron', 'wanted', 'to', 'do', 'something', 'that', 'had', 'a', 'tangible', 'impact', 'on', 'others', 'and', 'empowering', 'young', 'people', 'with', 'the', 'power', 'of', 'mathematics', 'provided', 'him', 'with', 'a', 'sense', 'hope', 'he', 'hadn', 't', 'had', 'for', 'a', 'long', 'time', 'so', 'on', 'tuesday', 'september', '16', 'fifty', 'three', 'year', 'old', 'ron', 'rockwell', 'finished', 'up', 'his', 'day', 'teaching', 'college', 'calculus', 'at', 'shippensburg', 'university', 'he', 'drove', 'his', '2007', 'white', 'toyota', 'camry', 'five', 'and', 'a', 'half', 'miles', 'to', 'his', 'two', 'bedroom', 'house', 'and', 'ordered', 'spring', 'rolls', 'and', 'chow', 'mein', 'for', 'delivery', 'when', 'it', 'arrived', 'he', 'didn', 't', 'tip', 'the', 'delivery', 'guy', 'he', 'sat', 'i ...

# %% [markdown]
# You can look at what the tokens are in the output.
#
# Let's define a short function to identify an introductory metric for our story. The Lexical Diversity represents the ratio of unique words used to the total number of words in the story.

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

lexical_diversity(tokens)
# Out:
# 0.3222842139809649

# %% [markdown]
# Let's check our math. How many tokens are there, total?

# %%
len(tokens)
# Out:
# 3047

# %% [markdown]
# How many unique tokens are there in that set?

# %%
len(set(tokens))
# Out:
# 982

# %% [markdown]
# 982/3047 is equal to a .32 Lexical Diversity score.
#
# The FreqDist() function turns our set of tokens into a Frequency Distribution object, giving us the frequencies of all tokens in my story.

# %%
fdist1 = FreqDist(tokens)
print(fdist1)
# Out:
# <FreqDist: 'the': 108, 'and': 105, 'to': 98, 'a': 82, 'of': 69, 'ron': 61, 'in': 56, 'i': 47, 'was': 47, 'his': 45, ...>

# %% [markdown]
# Let's have a quick look at our first ten items

# %%
fdist1.items()[0:10]
# Out:
# [('the', 108),
#  ('and', 105),
#  ('to', 98),
#  ('a', 82),
#  ('of', 69),
#  ('ron', 61),
#  ('in', 56),
#  ('i', 47),
#  ('was', 47),
#  ('his', 45)]

# %% [markdown]
# Not many of those words are useful for analysis. "The", "and", "to", "a", and "of" are all used in the English language to provide basic sentence structure. We want to eliminate these kinds of words and only focus on the words that have significance in giving us information about the story. These words are called "stopwords", and we are going to eliminate them by importing a pre-made list of stopwords and eliminating them from our list of word tokens.

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
remstop = [i for i in tokens if i not in stop]
remstop
# Out:
# ['\xef',
#  'today',
#  'remember',
#  'homework',
#  'due',
#  'next',
#  'class',
#  'forget',
#  'test',
#  'friday',
#  'everything',
#  've',
#  'learned',
#  'chain',
#  'rule',
#  'll',
#  'office',
#  'wednesday',
#  'twelve',
#  'two',
#  'thursday',
#  'three',
#  'four',
#  'college',
#  'calculus',
#  'boring',
#  'boring',
#  'students',
#  'homework',
#  'study',
#  'tests',
#  'even',
#  'though',
#  'many',
#  'class',
#  'fulfill',
#  'degree',
#  'requirement',
#  'boring',
#  'professor',
#  'come',
#  'class',
#  'stand',
#  'front',
#  '45',
#  'students',
#  'many',
#  'surfing',
#  'web',
#  'simply',
#  'copying',
#  'notes',
#  'like',
#  'robot',
#  'people',
#  'find',
#  'something',
#  'exciting',
#  'college',
#  'calculus',
#  'course',
#  'sense',
#  'ron',
#  'rockwell',
#  'perfect',
#  'college',
#  'calculus',
#  'professor',
#  'life',
#  'like',
#  'college',
#  'calculus',
#  'boring',
#  'weeks',
#  'consist',
#  'teaching',
#  'three',
#  'college',
#  'calculus',
#  'courses',
#  'differential',
#  'equations',
#  'course',
#  'research',
#  'mathematics',
#  'things',
#  'almost',
#  'steady',
#  'ron',
#  'rarely',
#  'get',
#  'excited',
#  'things',
#  'ron',
#  'get',
#  'excited',
#  'ron',
#  'tried',
#  'career',
#  'live',
#  'comfortable',
#  'normal',
#  'life',
#  'like',
#  'always',
#  'able',
#  'ron',
#  'succeeded',
#  'accomplished',
#  'goals',
#  'earned',
#  'degree',
#  'mathematics',
#  'brigham',
#  'young',
#  'university',
#  'though',
#  'wasn',
#  'exactly',
#  'mormon',
#  'scene',
#  'took',
#  'comfort',
#  'structure',
#  'peacefulness',
#  'culture',
#  'ron',
#  'described',
#  'colleagues',
#  'quite',
#  'passive',
#  'risk',
#  'averse',
#  'touch',
#  'arrogance',
#  'ron',
#  'went',
#  'work',
#  'insurance',
#  'set',
#  'goal',
#  'pass',
#  'exams',
#  'required',
#  'order',
#  'get',
#  'certified',
#  'enrolled',
#  'actuary',
#  'problem',
#  'ron',
#  'age',
#  '30',
#  'earning',
#  '85',
#  '000',
#  'per',
#  'year',
#  'could',
#  'negotiated',
#  'raise',
#  'ron',
#  'wasn',
#  'worth',
#  'trouble',
#  'age',
#  '40',
#  'earning',
#  '90',
#  '000',
#  'per',
#  'year',
#  'fiftieth',
#  'birthday',
#  'ron',
#  'quit',
#  'job',
#  'pursue',
#  'career',
#  'math',
#  'professor',
#  'ron',
#  'got',
#  'fed',
#  'crunching',
#  'numbers',
#  'people',
#  'sell',
#  'insurance',
#  'actually',
#  'ron',
#  'getting',
#  'fed',
#  'lot',
#  'things',
#  'failed',
#  'marriages',
#  'neighbors',
#  'general',
#  'monotony',
#  'daily',
#  'life',
#  'second',
#  'rate',
#  'new',
#  'jersey',
#  'suburbs',
#  'ron',
#  'wanted',
#  'something',
#  'tangible',
#  'impact',
#  'others',
#  'empowering',
#  'young',
#  'people',
#  'power',
#  'mathematics',
#  'provided',
#  'sense',
#  'hope',
#  'hadn',
#  'long',
#  'time',
#  'tuesday',
#  'september',
#  '16',
#  'fifty',
#  'three',
#  'year',
#  'old',
#  'ron',
#  'rockwell',
#  'finished',
#  'day',
#  'teaching',
#  'college',
#  'calculus',
#  'shippensburg',
#  'university',
#  'drove',
#  '2007',
#  'white',
#  'toyota',
#  'camry',
#  'five',
#  'half',
#  'miles',
#  'two',
#  'bedroom',
#  'house',
#  'ordered',
#  'spring',
#  'rolls',
#  'chow',
#  'mein',
#  'delivery',
#  'arrived',
#  'didn',
#  'tip',
#  'delivery',
#  'guy',
#  'sat',
#  'front',
#  'television',
#  'ate',
#  'food',
#  'went',
#  'bed',
#  'ron',
#  'woke',
#  'wednesday',
#  'september',
#  '17',
#  '7',
#  '45',
#  'prepared',
#  'day',
#  'ron',
#  'wednesday',
#  'outfit',
#  'included',
#  'untucked',
#  'polo',
#  'shirt',
#  'loose',
#  'fitting',
#  'khaki',
#  'pants',
#  'differential',
#  'equations',
#  'lecture',
#  '11',
#  '00',
#  'college',
#  'calculus',
#  'office',
#  'hours',
#  'slot',
#  '1',
#  '00',
#  '3',
#  '00',
#  'research',
#  'time',
#  'traffic',
#  'way',
#  'ron',
#  'struggled',
#  'additional',
#  '10',
#  'minutes',
#  'commute',
#  'normally',
#  'took',
#  '15',
#  'parking',
#  'car',
#  'campus',
#  'ron',
#  'spit',
#  'chewing',
#  'gum',
#  'onto',
#  'sidewalk',
#  'walked',
#  'office',
#  'ron',
#  'went',
#  'college',
#  'calculus',
#  'homework',
#  'still',
#  'needed',
#  'graded',
#  'amazed',
#  'poor',
#  'almost',
#  'seemed',
#  'like',
#  'students',
#  'pride',
#  'work',
#  '45',
#  'students',
#  'particular',
#  'batch',
#  '23',
#  'assignments',
#  'average',
#  'work',
#  '6',
#  'excellent',
#  '11',
#  'sub',
#  'par',
#  '5',
#  'didn',
#  'even',
#  'hand',
#  'something',
#  'average',
#  'score',
#  '2',
#  '2',
#  'possible',
#  'four',
#  'points',
#  'blatant',
#  'display',
#  'incompetence',
#  'bugging',
#  'ron',
#  'though',
#  'maybe',
#  'students',
#  'actually',
#  'legitimate',
#  'struggle',
#  'course',
#  'obvious',
#  'ron',
#  'class',
#  'underachieving',
#  'extremely',
#  'disengaged',
#  'envisioned',
#  'took',
#  'job',
#  'ron',
#  'genuinely',
#  'confused',
#  'would',
#  'student',
#  'pay',
#  'tuition',
#  'take',
#  'class',
#  'without',
#  'least',
#  'showing',
#  'sense',
#  'effort',
#  'interest',
#  '2',
#  '15',
#  'two',
#  'students',
#  'stopped',
#  'office',
#  'hours',
#  'mike',
#  'wanted',
#  'know',
#  'could',
#  'make',
#  'missed',
#  'homework',
#  'last',
#  'week',
#  'julio',
#  'legitimate',
#  'question',
#  'chain',
#  'rule',
#  'anticipation',
#  'friday',
#  'exam',
#  'ron',
#  'sighed',
#  'surfed',
#  'web',
#  'near',
#  'end',
#  'office',
#  'hours',
#  'one',
#  'ron',
#  'students',
#  'walked',
#  'molly',
#  'energetic',
#  'freshman',
#  'accounting',
#  'major',
#  'frustrated',
#  'calculus',
#  'lately',
#  'back',
#  'small',
#  'high',
#  'school',
#  'western',
#  'pennsylvania',
#  'molly',
#  'captain',
#  'cheerleading',
#  'squad',
#  'valedictorian',
#  'voted',
#  'classmates',
#  'likely',
#  'succeed',
#  'raised',
#  'mother',
#  'never',
#  'met',
#  'father',
#  'professor',
#  'rockwell',
#  'care',
#  'calculus',
#  'ron',
#  'looked',
#  'molly',
#  'blank',
#  'look',
#  'face',
#  'mean',
#  'understand',
#  'really',
#  'smart',
#  'people',
#  'use',
#  'm',
#  'business',
#  'student',
#  'm',
#  'going',
#  'integrals',
#  'm',
#  'auditing',
#  'client',
#  'ron',
#  'felt',
#  'torn',
#  'hope',
#  'frustration',
#  'one',
#  'hand',
#  'molly',
#  'seemed',
#  'genuinely',
#  'interested',
#  'finding',
#  'meaning',
#  'mathematics',
#  'new',
#  'exciting',
#  'development',
#  'teacher',
#  'still',
#  'fact',
#  'even',
#  'asked',
#  'question',
#  'sign',
#  'wasn',
#  'exactly',
#  'deep',
#  'thinker',
#  'molly',
#  'doubt',
#  'll',
#  'integrals',
#  'job',
#  'kpmg',
#  'chance',
#  'finish',
#  'course',
#  'll',
#  'never',
#  'take',
#  'another',
#  'limit',
#  'derivative',
#  'ever',
#  'even',
#  'case',
#  'tell',
#  'think',
#  'good',
#  'take',
#  'calculus',
#  'molly',
#  'stared',
#  'know',
#  'asked',
#  'replied',
#  'flatly',
#  'second',
#  'time',
#  'semester',
#  'came',
#  'office',
#  'hours',
#  'first',
#  'time',
#  'came',
#  'ask',
#  'points',
#  'back',
#  'assignment',
#  'ron',
#  'gave',
#  'points',
#  'even',
#  'though',
#  'didn',
#  'deserve',
#  'professor',
#  'rockwell',
#  'tried',
#  'best',
#  'craft',
#  'gentle',
#  'helpful',
#  'response',
#  'molly',
#  'though',
#  'day',
#  'day',
#  'business',
#  'might',
#  'require',
#  'understand',
#  'riemann',
#  'sums',
#  'chain',
#  'rule',
#  'calculus',
#  'work',
#  'behind',
#  'interesting',
#  'useful',
#  'things',
#  'human',
#  'civilization',
#  'offer',
#  'citizen',
#  'world',
#  'knowledge',
#  'calculus',
#  'enrich',
#  'existence',
#  'gives',
#  'leg',
#  'haven',
#  'connected',
#  'dots',
#  'molly',
#  'fascinated',
#  'answer',
#  'interesting',
#  'way',
#  'putting',
#  'teach',
#  'us',
#  'like',
#  'recall',
#  'lesson',
#  've',
#  'given',
#  'us',
#  'connected',
#  'world',
#  'around',
#  'us',
#  'think',
#  'students',
#  'would',
#  'enjoy',
#  'course',
#  'provided',
#  'us',
#  'context',
#  'class',
#  'professor',
#  'impressed',
#  'straightforward',
#  'molly',
#  'actually',
#  'agreed',
#  'amount',
#  'math',
#  'covered',
#  'didn',
#  'leave',
#  'time',
#  'digressions',
#  'conversation',
#  'class',
#  'answer',
#  'agreed',
#  'everything',
#  'said',
#  'wiggle',
#  'room',
#  'make',
#  'changes',
#  'class',
#  'moment',
#  'felt',
#  'sad',
#  'powerless',
#  'thursday',
#  'september',
#  '18',
#  'ron',
#  'woke',
#  'seemed',
#  'like',
#  'approaching',
#  'morning',
#  'thunderstorm',
#  'rain',
#  'falling',
#  'sky',
#  'stormy',
#  'gray',
#  'thunder',
#  'could',
#  'heard',
#  'lightning',
#  'strikes',
#  'distance',
#  'ron',
#  'fixed',
#  'coffee',
#  'went',
#  'outside',
#  'porch',
#  'side',
#  'house',
#  'get',
#  'breath',
#  'fresh',
#  'air',
#  'looked',
#  'sky',
#  'enjoyed',
#  'power',
#  'nature',
#  'reason',
#  'ron',
#  'always',
#  'loved',
#  'watching',
#  'storms',
#  'bolt',
#  'lightning',
#  'flashed',
#  'sky',
#  'right',
#  'ron',
#  'eyes',
#  'simultaneously',
#  'terrifying',
#  'powerful',
#  'thunder',
#  'clap',
#  'rocked',
#  'knocking',
#  'feet',
#  'spilling',
#  'coffee',
#  'fight',
#  'flight',
#  'immediately',
#  'took',
#  'sound',
#  'lingered',
#  'seemed',
#  'full',
#  '60',
#  'seconds',
#  'slowly',
#  'decreasing',
#  'magnitude',
#  'dogs',
#  'barked',
#  'birds',
#  'torpedoed',
#  'away',
#  'strike',
#  'ron',
#  'screamed',
#  'somersaulted',
#  'roof',
#  'porch',
#  'heart',
#  'pulsing',
#  'first',
#  'time',
#  'decades',
#  'truly',
#  'felt',
#  'fear',
#  'life',
#  'roughly',
#  '140',
#  'seconds',
#  'passed',
#  'ron',
#  'felt',
#  'heat',
#  'coffee',
#  'right',
#  'side',
#  'still',
#  'shaking',
#  'hyperventilating',
#  'overdose',
#  'anxiety',
#  'staggered',
#  'inside',
#  'grab',
#  'towel',
#  'clean',
#  'coffee',
#  'sweat',
#  'noticed',
#  'left',
#  'elbow',
#  'bleeding',
#  'tumble',
#  'pavement',
#  'lightning',
#  'struck',
#  'time',
#  'distance',
#  'ron',
#  'froze',
#  'thunder',
#  'rolled',
#  'mile',
#  'distance',
#  'ron',
#  'noticed',
#  'large',
#  'tree',
#  'glowing',
#  'ember',
#  'branches',
#  'smoke',
#  'rising',
#  'took',
#  '45',
#  'minutes',
#  'ron',
#  'adrenaline',
#  'reach',
#  'baseline',
#  'level',
#  'light',
#  'show',
#  'moved',
#  'away',
#  'storm',
#  'clouds',
#  'remained',
#  'trace',
#  'ron',
#  'analytical',
#  'mind',
#  'finally',
#  'started',
#  'come',
#  'back',
#  'since',
#  'primal',
#  'instincts',
#  'took',
#  'total',
#  'control',
#  'like',
#  'reasoned',
#  'lightning',
#  'within',
#  '200',
#  'meters',
#  'house',
#  'since',
#  'frame',
#  'reference',
#  'virtually',
#  'gap',
#  'bolt',
#  'boom',
#  'considered',
#  'lightning',
#  'could',
#  'easily',
#  'struck',
#  'quarter',
#  'mile',
#  'west',
#  'zapped',
#  'oblivion',
#  'life',
#  'seemed',
#  'precious',
#  'ron',
#  'began',
#  'feel',
#  'sense',
#  'urgency',
#  'life',
#  'never',
#  'felt',
#  'lightning',
#  'could',
#  'strike',
#  'nowhere',
#  'really',
#  'make',
#  'sense',
#  'live',
#  'passive',
#  'existence',
#  'goals',
#  'anyway',
#  'chasing',
#  'life',
#  'ron',
#  'cruised',
#  'friday',
#  'morning',
#  'calculus',
#  'class',
#  'royal',
#  'blue',
#  'dress',
#  'shirt',
#  'tucked',
#  'best',
#  'fitting',
#  'gray',
#  'trousers',
#  'greeted',
#  'molly',
#  'eager',
#  'hello',
#  'sitting',
#  'front',
#  'row',
#  'chatting',
#  'girl',
#  'next',
#  'students',
#  'turned',
#  'head',
#  'ron',
#  'merrily',
#  'acknowledged',
#  'member',
#  'class',
#  'without',
#  'reference',
#  'calculus',
#  'today',
#  'first',
#  'time',
#  'semester',
#  'ron',
#  'didn',
#  'start',
#  'class',
#  'turning',
#  'back',
#  'writing',
#  'board',
#  'students',
#  'looked',
#  'electronic',
#  'devices',
#  'took',
#  'notice',
#  'abnormality',
#  'weren',
#  'however',
#  'intrigued',
#  'enough',
#  'manage',
#  'response',
#  'greeting',
#  'today',
#  'going',
#  'continue',
#  'discussion',
#  'integration',
#  'parts',
#  'thought',
#  'friday',
#  've',
#  'working',
#  'hard',
#  'could',
#  'take',
#  'day',
#  'discuss',
#  'everything',
#  've',
#  'learning',
#  'fits',
#  'context',
#  'mathematics',
#  'life',
#  'general',
#  'entire',
#  'class',
#  'nothing',
#  'stare',
#  'back',
#  'professor',
#  'think',
#  'sometimes',
#  'get',
#  'lost',
#  'technicality',
#  'rigor',
#  'mathematics',
#  'result',
#  'lose',
#  'focus',
#  'reason',
#  'important',
#  'study',
#  'ideas',
#  'first',
#  'place',
#  'students',
#  'continued',
#  'stare',
#  'back',
#  'molly',
#  'smiled',
#  'today',
#  're',
#  'going',
#  ...]

# %% [markdown]
# How many total words are left?

# %%
len(remstop)
# Out:
# 1542

# %% [markdown]
# How many unique words made it?

# %%
len(set(remstop))
# Out:
# 876

# %% [markdown]
# Let's turn our stopword-free list of tokens into a Frequency Distribution object.

# %%
fdist2 = FreqDist(remstop)
print(fdist2)
# Out:
# <FreqDist: 'ron': 61, 'molly': 25, 'calculus': 16, 'students': 15, 'class': 13, 'time': 13, 'mathematics': 10, 'really': 10, 'wasn': 10, 'know': 9, ...>

# %% [raw]
# Now we're getting somewhere. Let's see a list of the top 20 most common non-stopwords in my short story, Ron Rockwell.

# %%
fdist2.items()[0:20]
# Out:
# [('ron', 61),
#  ('molly', 25),
#  ('calculus', 16),
#  ('students', 15),
#  ('class', 13),
#  ('time', 13),
#  ('mathematics', 10),
#  ('really', 10),
#  ('wasn', 10),
#  ('know', 9),
#  ('life', 9),
#  ('office', 9),
#  ('professor', 9),
#  ('took', 9),
#  ('college', 8),
#  ('wanted', 8),
#  ('felt', 7),
#  ('get', 7),
#  ('like', 7),
#  ('things', 7)]

# %% [markdown]
# This makes a lot more sense. The top two most common words are the names of the two main characters, Ron and Molly. The third most common word, "calculus", is how they are connected: Ron is the professor for Molly's calculus class. The next four most common words, "students", "class", "time", and "mathematics" seem to make sense in this context.
#
# Ok, that's pretty neat. Now let's take a measure of how rich our vocabulary was with the stopwords removed.

# %%
lexical_diversity(remstop)
# Out:
# 0.5680933852140078

# %% [markdown]
# That's higher than the .32 score we saw earlier. Removing all those common stopwords makes obviously makes our use of language seem more diverse.
#
# Ok, so in order to save some of this data for later--in this case, the top 20 most common non-stopwords, we'll turn that into a list, which we'll then write out as a .csv file.

# %%
array = fdist2.items()[0:20]
mylist = [list(i) for i in array]

# %% [markdown]
# Finally, we can take this data and export it as a .csv file for further analysis in R or Excel.

# %%
import csv
with open('newfile.csv', 'wb') as result:
    writer = csv.writer(result, dialect='excel')
    writer.writerows(array)

with open('tokens.csv', 'wb') as result:
    writer = csv.writer(result, dialect='excel')
    writer.writerow(remstop)

# %% [markdown]
# You can download the files here as proof that this worked:
